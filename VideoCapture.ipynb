# %%
import numpy as np
import cv2
import glob, os
import PIL
import shutil    
    
cap = cv2.VideoCapture(0)

currentframe = 0 

fourcc = cv2.VideoWriter_fourcc(*'XVID')
out = cv2.VideoWriter('output.avi', fourcc, 20.0, (640, 480))

while True:
    ret, frame = cap.read()

    cv2.imwrite("frame" + str(currentframe) + ".jpg", frame)
    currentframe +=1
    
    out.write(frame)
    
    
    #width = int(cap.get(3))
    #height = int(cap.get(4))

    #image = np.zeros(frame.shape, np.uint8)
    #smaller_frame = cv2.resize(frame, (0, 0), fx=0.5, fy=0.5)
    #image[:height//2, :width//2] = cv2.rotate(smaller_frame, cv2.cv2.ROTATE_180)
    #image[height//2:, :width//2] = smaller_frame
    #image[:height//2, width//2:] = cv2.rotate(smaller_frame, cv2.cv2.ROTATE_180)
    #image[height//2:, width//2:] = smaller_frame
    
    cv2.imshow("Video", frame)

    
    if cv2.waitKey(1)&0xFF == ord('q'):
        break

cap.release()
out.release()
cv2.destroyAllWindows()



src_folder = r"C:\Users\Prothoma Yousra\Desktop\AI\Video and Frames Capture\Video Capture"
dst_folder = r"C:\Users\Prothoma Yousra\Desktop\AI\Video and Frames Capture\VideosAndFrames"

pattern = "\*.jpg"
files = glob.glob(src_folder + pattern)

for file in files:
    shutil.move(file, os.path.join(dst_folder, "Frames"))
    print('Moved:', file)
# Out:
# Moved: C:\Users\Prothoma Yousra\Desktop\AI\Video and Frames Capture\Video Capture\frame0.jpg
# Moved: C:\Users\Prothoma Yousra\Desktop\AI\Video and Frames Capture\Video Capture\frame1.jpg
# Moved: C:\Users\Prothoma Yousra\Desktop\AI\Video and Frames Capture\Video Capture\frame10.jpg
# Moved: C:\Users\Prothoma Yousra\Desktop\AI\Video and Frames Capture\Video Capture\frame100.jpg
# Moved: C:\Users\Prothoma Yousra\Desktop\AI\Video and Frames Capture\Video Capture\frame101.jpg
# Moved: C:\Users\Prothoma Yousra\Desktop\AI\Video and Frames Capture\Video Capture\frame102.jpg
# Moved: C:\Users\Prothoma Yousra\Desktop\AI\Video and Frames Capture\Video Capture\frame103.jpg
# Moved: C:\Users\Prothoma Yousra\Desktop\AI\Video and Frames Capture\Video Capture\frame104.jpg
# Moved: C:\Users\Prothoma Yousra\Desktop\AI\Video and Frames Capture\Video Capture\frame105.jpg
# Moved: C:\Users\Prothoma Yousra\Desktop\AI\Video and Frames Capture\Video Capture\frame106.jpg
# ...
